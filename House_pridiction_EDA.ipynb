# %%
# Exploratory Data Analysis (EDA) is the process of examining and summarizing a dataset to uncover patterns, trends, relationships,
# and anomalies. It involves using statistical summaries (e.g., mean, median), visualizations (e.g., histograms, scatter plots), 
# and data cleaning techniques to understand the data’s structure, assess its quality, and generate hypotheses for further analysis.
# EDA is a critical first step in data science workflows, often leveraging tools like Python (Pandas, Matplotlib, Seaborn) 
# or R within platforms like Jupyter Notebook to iteratively explore and communicate insights.

# %% [markdown]
# ## Problem statement for Housing Data EDA

# %%
Objective: Perform an exploratory data analysis (EDA) on a housing dataset to uncover insights into factors influencing property prices, identify patterns or anomalies, and prepare the data for predictive modeling (e.g., price prediction).

Key Questions to Address:

Data Understanding:

What variables (e.g., square footage, location, bedrooms, year built) are most strongly correlated with housing prices?

How are numerical and categorical features distributed?

Data Quality:

Are there missing values, duplicates, or outliers in the dataset?

How should anomalies (e.g., unusually high/low prices) be handled?

Trends and Relationships:

How do property prices vary by location (e.g., zip code, neighborhood)?

Is there a relationship between house age, renovation status, and price?

Do amenities (e.g., pools, garages) impact prices significantly?

Market Insights:

What are the average prices for different property types (e.g., single-family homes, condos)?

Are there seasonal trends in housing sales or prices?

Expected Outcomes:

Cleaned and preprocessed dataset ready for modeling.

Visualizations (e.g., heatmaps, box plots, scatter plots) highlighting key relationships.

Insights into drivers of housing prices and actionable recommendations (e.g., features to prioritize for valuation models).

Tools: Python (Pandas, Matplotlib, Seaborn), Jupyter Notebook for iterative analysis and documentation.

Example Workflow:

Load and inspect the dataset (summary statistics, data types).

Handle missing values and outliers.

Analyze distributions (e.g., price, square footage).

Explore correlations (e.g., price vs. bedrooms, location).

Visualize spatial trends (e.g., price heatmaps by region).

Summarize findings and propose next steps (e.g., feature engineering for regression models).

This framework guides the EDA process while aligning with real-world housing market analysis goals.

# %% [markdown]
# ## Importing all important libraries for this project

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression,Ridge,ElasticNet,Lasso
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor, VotingRegressor, StackingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
import re
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # imported data through pandas

# %%
df=pd.read_csv(r"C:\Users\kulde\Desktop\project\Project_3\housing_data.csv")
df
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Reg         Lvl    AllPub  ...        0     No     No          No
# 1         Reg         Lvl    AllPub  ...        0     No     No          No
# 2         IR1         Lvl    AllPub  ...        0     No     No          No
# 3         IR1         Lvl    AllPub  ...        0     No     No          No
# 4         IR1         Lvl    AllPub  ...        0     No     No          No
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1457      Reg         Lvl    AllPub  ...        0     No  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0    Feb   2008        WD         Normal     208500
# 1          0    May   2007        WD         Normal     181500
# 2          0    Sep   2008        WD         Normal     223500
# 3          0    Feb   2006        WD        Abnorml     140000
# 4          0    Dec   2008        WD         Normal     250000
# ...      ...    ...    ...       ...            ...        ...
# 1455       0    Aug   2007        WD         Normal     175000
# 1456       0    Feb   2010        WD         Normal     210000
# 1457    2500    May   2010        WD         Normal     266500
# 1458       0    Apr   2010        WD         Normal     142125
# 1459       0    Jun   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# # lets figure out the shape of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1460 non-null   int64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1460 non-null   object
#  31  BsmtCond       1460 non-null   object
#  32  BsmtExposure   1460 non-null   object
#  33  BsmtFinType1   1460 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1460 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    1460 non-null   object
#  58  GarageType     1460 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1460 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1460 non-null   object
#  64  GarageCond     1460 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         1460 non-null   object
#  73  Fence          1460 non-null   object
#  74  MiscFeature    1460 non-null   object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   object
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(1), int64(35), object(45)
# memory usage: 924.0+ KB

# %%
df.describe()
#This function is describe the int and float colomn in the data like it have count, mean , standard deviton, min & max value percentile etc
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   164.250000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    472.980137    94.244521    46.660274      21.954110     3.409589
# std     213.804841   125.338794    66.256028      61.119149    29.317331
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     334.500000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    25.000000       0.000000     0.000000
# 75%     576.000000   168.000000    68.000000       0.000000     0.000000
# max    1418.000000   857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       YrSold      SalePrice
# count  1460.000000  1460.000000   1460.000000  1460.000000    1460.000000
# mean     15.060959     2.758904     43.489041  2007.815753  180921.195890
# std      55.757415    40.177307    496.123024     1.328095   79442.502883
# min       0.000000     0.000000      0.000000  2006.000000   34900.000000
# 25%       0.000000     0.000000      0.000000  2007.000000  129975.000000
# 50%       0.000000     0.000000      0.000000  2008.000000  163000.000000
# 75%       0.000000     0.000000      0.000000  2009.000000  214000.000000
# max     480.000000   738.000000  15500.000000  2010.000000  755000.000000
#
# [8 rows x 36 columns]

# %%
df.dtypes[df.dtypes!="object"]
# Out:
# Unnamed: 0         int64
# LotFrontage        int64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea         int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %% [markdown]
# ## i am making scatter plot in whole data one by one to find out the outlier which is majorly empacting the data for create LMS model
# ## for predicting the sales price of the house.

# %%
sn.violinplot(x="GarageType", y="SalePrice", data=df, palette="husl", inner="box")
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Your code goes here

# %%
plt.scatter(x="MSSubClass", y="SalePrice",data=df  )

# %%
sn.jointplot(data=df, x="YearBuilt", y="SalePrice", hue="SalePrice")

# %%
plt.scatter(x="LotFrontage", y="SalePrice",data=df  )

# %%
df.query("LotFrontage>300")
# drop 934,1298
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 934          934       SC20       RL          313    27650   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 934       IR2         HLS    AllPub  ...        0     No    No          No
# 1298      IR3         Bnk    AllPub  ...      480     Gd    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 934        0    Nov   2008        WD         Normal     242000
# 1298       0    Jan   2008       New        Partial     160000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x="LotArea", y="SalePrice",data=df  )

# %%
df.query("LotArea>55000")
# drop 294,313,335,451,706,1298,
#(1396) may be
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 249          249       SC50       RL            0   159000   Pave   NaN
# 313          313       SC20       RL          150   215245   Pave   NaN
# 335          335      SC190       RL            0   164660   Grvl   NaN
# 451          451       SC20       RL           62    70761   Pave   NaN
# 706          706       SC20       RL            0   115149   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
# 1396        1396       SC20       RL            0    57200   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 249       IR2         Low    AllPub  ...        0     No    No        Shed
# 313       IR3         Low    AllPub  ...        0     No    No          No
# 335       IR1         HLS    AllPub  ...        0     No    No        Shed
# 451       IR1         Low    AllPub  ...        0     No    No          No
# 706       IR2         Low    AllPub  ...        0     No    No          No
# 1298      IR3         Bnk    AllPub  ...      480     Gd    No          No
# 1396      IR1         Bnk    AllPub  ...        0     No    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 249      500    Jun   2007        WD         Normal     277000
# 313        0    Jun   2009        WD         Normal     375000
# 335      700    Aug   2008        WD         Normal     228950
# 451        0    Dec   2006        WD         Normal     280000
# 706        0    Jun   2007        WD         Normal     302000
# 1298       0    Jan   2008       New        Partial     160000
# 1396       0    Jun   2010        WD         Normal     160000
#
# [7 rows x 81 columns]

# %%
stats.zscore(df["LotArea"]).sort_values().tail(10)
# 313,335,249,
# Out:
# 384      4.268474
# 457      4.280500
# 769      4.308262
# 1396     4.678682
# 1298     5.348867
# 451      6.037793
# 706     10.486449
# 249     14.881285
# 335     15.448542
# 313     20.518273
# Name: LotArea, dtype: float64

# %%
plt.scatter(x="OverallQual",  y="SalePrice",data=df)

# %%
df.query("OverallQual==10" )
# here overallqual means over all quality of house/building/apartment 
# may be 523
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 58            58       SC60       RL           66    13682   Pave   NaN
# 185          185       SC75       RM           90    22950   Pave   NaN
# 224          224       SC20       RL          103    13472   Pave   NaN
# 389          389       SC60       RL           96    12474   Pave   NaN
# 440          440       SC20       RL          105    15431   Pave   NaN
# 515          515       SC20       RL           94    12220   Pave   NaN
# 523          523       SC60       RL          130    40094   Pave   NaN
# 583          583       SC75       RM           75    13500   Pave   NaN
# 591          591       SC60       RL           97    13478   Pave   NaN
# 691          691       SC60       RL          104    21535   Pave   NaN
# 825          825       SC20       RL          114    14803   Pave   NaN
# 994          994       SC20       RL           96    12456   Pave   NaN
# 1169        1169       SC60       RL          118    35760   Pave   NaN
# 1182        1182       SC60       RL          160    15623   Pave   NaN
# 1243        1243       SC20       RL          107    13891   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
# 1373        1373       SC20       RL            0    11400   Pave   NaN
# 1442        1442       SC60       FV           85    11003   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 58        IR2         HLS    AllPub  ...        0     No     No          No
# 185       IR2         Lvl    AllPub  ...        0     No  GdPrv          No
# 224       Reg         Lvl    AllPub  ...        0     No     No          No
# 389       Reg         Lvl    AllPub  ...        0     No     No          No
# 440       Reg         Lvl    AllPub  ...        0     No     No          No
# 515       Reg         Lvl    AllPub  ...        0     No     No          No
# 523       IR1         Bnk    AllPub  ...        0     No     No          No
# 583       Reg         Lvl    AllPub  ...        0     No     No          No
# 591       IR1         Lvl    AllPub  ...        0     No     No          No
# 691       IR1         Lvl    AllPub  ...        0     No     No          No
# 825       Reg         Lvl    AllPub  ...        0     No     No          No
# 994       Reg         Lvl    AllPub  ...        0     No     No          No
# 1169      IR1         Lvl    AllPub  ...        0     No     No          No
# 1182      IR1         Lvl    AllPub  ...      555     Ex  MnPrv          No
# 1243      Reg         Lvl    AllPub  ...        0     No     No          No
# 1298      IR3         Bnk    AllPub  ...      480     Gd     No          No
# 1373      Reg         Lvl    AllPub  ...        0     No     No          No
# 1442      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 58         0    Oct   2006       New        Partial     438780
# 185        0    Jun   2006        WD         Normal     475000
# 224        0    Jun   2009        WD         Normal     386250
# 389        0    Aug   2008       New        Partial     426000
# 440        0    Apr   2009        WD         Normal     555000
# 515        0    Sep   2009       New        Partial     402861
# 523        0    Oct   2007       New        Partial     184750
# 583        0    Jul   2008        WD         Normal     325000
# 591        0    Jun   2009     ConLI         Normal     451950
# 691        0    Jan   2007        WD         Normal     755000
# 825        0    Jun   2008       New        Partial     385000
# 994        0    Jul   2009        WD         Normal     337500
# 1169       0    Jul   2006        WD         Normal     625000
# 1182       0    Jul   2007        WD        Abnorml     745000
# 1243       0    Sep   2006       New        Partial     465000
# 1298       0    Jan   2008       New        Partial     160000
# 1373       0    Mar   2007        WD         Normal     466500
# 1442       0    Apr   2009        WD         Normal     310000
#
# [18 rows x 81 columns]

# %%
plt.scatter(x="OverallCond", y="SalePrice", data=df )

# %%
df.query("OverallCond==2" )
#378
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 88           88       SC50  C (all)          105     8470   Pave   NaN
# 250         250       SC30       RL           55     5350   Pave   NaN
# 378         378       SC20       RL           88    11394   Pave   NaN
# 398         398       SC30       RM           60     8967   Pave   NaN
# 676         676       SC70       RM           60     9600   Pave  Grvl
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 88       IR1         Lvl    AllPub  ...        0     No  MnPrv          No
# 250      IR1         Lvl    AllPub  ...        0     No   GdWo        Shed
# 378      Reg         Lvl    AllPub  ...        0     No     No          No
# 398      Reg         Lvl    AllPub  ...        0     No     No          No
# 676      Reg         Lvl    AllPub  ...        0     No     No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 88        0    Oct   2009     ConLD        Abnorml      85000
# 250     450    May   2010        WD         Normal      76500
# 378       0    Jun   2010       New        Partial     394432
# 398       0    Nov   2007        WD        Abnorml      67000
# 676       0    May   2006        WD         Normal      87000
#
# [5 rows x 81 columns]

# %%
df.query("OverallCond==5 &  SalePrice>70000")
#1183
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# 5              5       SC50       RL           85    14115   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1451        1451       SC20       RL           78     9262   Pave   NaN
# 1452        1452      SC180       RM           35     3675   Pave   NaN
# 1453        1453       SC20       RL           90    17217   Pave   NaN
# 1454        1454       SC20       FV           62     7500   Pave  Pave
# 1455        1455       SC60       RL           62     7917   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Reg         Lvl    AllPub  ...        0     No     No          No
# 2         IR1         Lvl    AllPub  ...        0     No     No          No
# 3         IR1         Lvl    AllPub  ...        0     No     No          No
# 4         IR1         Lvl    AllPub  ...        0     No     No          No
# 5         IR1         Lvl    AllPub  ...        0     No  MnPrv        Shed
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1451      Reg         Lvl    AllPub  ...        0     No     No          No
# 1452      Reg         Lvl    AllPub  ...        0     No     No          No
# 1453      Reg         Lvl    AllPub  ...        0     No     No          No
# 1454      Reg         Lvl    AllPub  ...        0     No     No          No
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0    Feb   2008        WD         Normal     208500
# 2          0    Sep   2008        WD         Normal     223500
# 3          0    Feb   2006        WD        Abnorml     140000
# 4          0    Dec   2008        WD         Normal     250000
# 5        700    Oct   2009        WD         Normal     143000
# ...      ...    ...    ...       ...            ...        ...
# 1451       0    May   2009       New        Partial     287090
# 1452       0    May   2006        WD         Normal     145000
# 1453       0    Jul   2006        WD        Abnorml      84500
# 1454       0    Oct   2009        WD         Normal     185000
# 1455       0    Aug   2007        WD         Normal     175000
#
# [816 rows x 81 columns]

# %%
df.isnull().sum().sum()
# Out:
# 2323

# %%
df.query("OverallCond==6 & SalePrice>70000")
#692
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 7              7       SC60       RL            0    10382   Pave   NaN
# 9              9      SC190       RL           50     7420   Pave   NaN
# 12            12       SC20       RL            0    12968   Pave   NaN
# 19            19       SC20       RL           70     7560   Pave   NaN
# 28            28       SC20       RL           47    16321   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1439        1439       SC60       RL           80    11584   Pave   NaN
# 1443        1443       SC30       RL            0     8854   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 7         IR1         Lvl    AllPub  ...        0     No     No        Shed
# 9         Reg         Lvl    AllPub  ...        0     No     No          No
# 12        IR2         Lvl    AllPub  ...        0     No     No          No
# 19        Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 28        IR1         Lvl    AllPub  ...        0     No     No          No
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1439      Reg         Lvl    AllPub  ...        0     No     No          No
# 1443      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 7        350    Nov   2009        WD         Normal     200000
# 9          0    Jan   2008        WD         Normal     118000
# 12         0    Sep   2008        WD         Normal     144000
# 19         0    May   2009       COD        Abnorml     139000
# 28         0    Dec   2006        WD         Normal     207500
# ...      ...    ...    ...       ...            ...        ...
# 1439       0    Nov   2007        WD         Normal     197000
# 1443       0    May   2009        WD         Normal     121000
# 1456       0    Feb   2010        WD         Normal     210000
# 1458       0    Apr   2010        WD         Normal     142125
# 1459       0    Jun   2008        WD         Normal     147500
#
# [247 rows x 81 columns]

# %%
plt.scatter(x="YearBuilt", y="SalePrice", data=df )

# %%
df.query("YearBuilt<1900 & SalePrice>40000")
#185
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 106          106       SC30       RM           60    10800   Pave  Grvl
# 185          185       SC75       RM           90    22950   Pave   NaN
# 304          304       SC75       RM           87    18386   Pave   NaN
# 583          583       SC75       RM           75    13500   Pave   NaN
# 630          630       SC70       RM           50     9000   Pave  Grvl
# 716          716       SC70       RM           60    10800   Pave  Grvl
# 747          747       SC70       RM           65    11700   Pave  Pave
# 809          809       SC75       RM           90     8100   Pave   NaN
# 945          945       SC50       RM           98     8820   Pave   NaN
# 991          991       SC70       RM          121    17671   Pave  Grvl
# 1132        1132       SC70       RM           90     9900   Pave   NaN
# 1137        1137       SC50       RL           54     6342   Pave   NaN
# 1292        1292       SC70       RM           60     6600   Pave   NaN
# 1349        1349       SC70       RM           50     5250   Pave  Pave
# 1416        1416      SC190       RM           60    11340   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 106       Reg         Lvl    AllPub  ...        0     No     No        Shed
# 185       IR2         Lvl    AllPub  ...        0     No  GdPrv          No
# 304       Reg         Lvl    AllPub  ...        0     No     No          No
# 583       Reg         Lvl    AllPub  ...        0     No     No          No
# 630       Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 716       Reg         Bnk    AllPub  ...        0     No     No          No
# 747       IR1         Lvl    AllPub  ...        0     No     No          No
# 809       Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 945       Reg         Lvl    AllPub  ...        0     No   MnWw          No
# 991       Reg         Lvl    AllPub  ...        0     No     No          No
# 1132      Reg         Lvl    AllPub  ...        0     No     No          No
# 1137      Reg         Lvl    AllPub  ...        0     No     No          No
# 1292      Reg         Lvl    AllPub  ...        0     No     No          No
# 1349      Reg         Lvl    AllPub  ...        0     No     No          No
# 1416      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 106      450    Aug   2007        WD         Normal     100000
# 185        0    Jun   2006        WD         Normal     475000
# 304        0    May   2008        WD         Normal     295000
# 583        0    Jul   2008        WD         Normal     325000
# 630        0    Jun   2006        WD        Abnorml     124000
# 716        0    Jul   2007        WD         Normal     159500
# 747        0    May   2009        WD         Normal     265979
# 809        0    Nov   2009        WD         Normal     106000
# 945        0    Sep   2009        WD         Normal     124900
# 991        0    Nov   2009        WD         Normal     168000
# 1132       0    May   2007        WD         Normal     117500
# 1137       0    May   2010        WD         Normal      94000
# 1292       0    Dec   2009        WD         Normal     107500
# 1349       0    Dec   2008        WD         Normal     122000
# 1416       0    Apr   2010        WD         Normal     122500
#
# [15 rows x 81 columns]

# %%
plt.scatter(x="YearRemodAdd", y="SalePrice", data=df )

# %%
df.query("YearRemodAdd<1970 & SalePrice>30000")
#313
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 8              8       SC50       RM           51     6120   Pave   NaN
# 9              9      SC190       RL           50     7420   Pave   NaN
# 10            10       SC20       RL           70    11200   Pave   NaN
# 12            12       SC20       RL            0    12968   Pave   NaN
# 14            14       SC20       RL            0    10920   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1427        1427       SC50       RL           60    10930   Pave  Grvl
# 1443        1443       SC30       RL            0     8854   Pave   NaN
# 1445        1445       SC85       RL           70     8400   Pave   NaN
# 1446        1446       SC20       RL            0    26142   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 8         Reg         Lvl    AllPub  ...        0     No    No          No
# 9         Reg         Lvl    AllPub  ...        0     No    No          No
# 10        Reg         Lvl    AllPub  ...        0     No    No          No
# 12        IR2         Lvl    AllPub  ...        0     No    No          No
# 14        IR1         Lvl    AllPub  ...        0     No  GdWo          No
# ...       ...         ...       ...  ...      ...    ...   ...         ...
# 1427      Reg         Bnk    AllPub  ...        0     No    No          No
# 1443      Reg         Lvl    AllPub  ...        0     No    No          No
# 1445      Reg         Lvl    AllPub  ...        0     No    No          No
# 1446      IR1         Lvl    AllPub  ...        0     No    No          No
# 1459      Reg         Lvl    AllPub  ...        0     No    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 8          0    Apr   2008        WD        Abnorml     129900
# 9          0    Jan   2008        WD         Normal     118000
# 10         0    Feb   2008        WD         Normal     129500
# 12         0    Sep   2008        WD         Normal     144000
# 14         0    May   2008        WD         Normal     157000
# ...      ...    ...    ...       ...            ...        ...
# 1427       0    Apr   2008        WD         Normal     140000
# 1443       0    May   2009        WD         Normal     121000
# 1445       0    May   2007        WD         Normal     129000
# 1446       0    Apr   2010        WD         Normal     157900
# 1459       0    Jun   2008        WD         Normal     147500
#
# [407 rows x 81 columns]

# %%
plt.scatter(x="MasVnrArea", y="SalePrice", data=df )

# %%
df.query("MasVnrArea>1500")
#297
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 297         297       SC60       FV           66     7399   Pave  Pave
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 297      IR1         Lvl    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 297       0    Jun   2007        WD         Normal     239000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="BsmtFinSF1", y="SalePrice", data=df )

# %%
df.query("BsmtFinSF1 >5000")
#1298
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 1298      IR3         Bnk    AllPub  ...      480     Gd    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298       0    Jan   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="BsmtFinSF2", y="SalePrice", data=df )

# %%
df.query("BsmtFinSF2 > 1400 & SalePrice>50000")

#440
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 322         322       SC60       RL           86    10380   Pave   NaN
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 322      IR1         Lvl    AllPub  ...        0     No  MnPrv          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 322       0    Aug   2007        WD         Normal     301000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="BsmtUnfSF", y="SalePrice", data=df )

# %%
plt.scatter(x="TotalBsmtSF", y="SalePrice", data=df )

# %%
df.query("TotalBsmtSF>6000")
#1298
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 1298      IR3         Bnk    AllPub  ...      480     Gd    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298       0    Jan   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="1stFlrSF", y="SalePrice", data=df )

# %%
plt.scatter(x="2ndFlrSF", y="SalePrice", data=df )

# %%
plt.scatter(x="LowQualFinSF", y="SalePrice", data=df )

# %%
df.query("LowQualFinSF>500 & SalePrice >40000")
# 185
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 88            88       SC50  C (all)          105     8470   Pave   NaN
# 170          170       SC50       RM            0    12358   Pave   NaN
# 185          185       SC75       RM           90    22950   Pave   NaN
# 635          635      SC190       RH           60    10896   Pave  Pave
# 1009        1009       SC50       RL           60     6000   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 88        IR1         Lvl    AllPub  ...        0     No  MnPrv          No
# 170       IR1         Lvl    AllPub  ...        0     No     No          No
# 185       IR2         Lvl    AllPub  ...        0     No  GdPrv          No
# 635       Reg         Bnk    AllPub  ...        0     No     No          No
# 1009      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 88         0    Oct   2009     ConLD        Abnorml      85000
# 170        0    May   2007        WD         Normal     128500
# 185        0    Jun   2006        WD         Normal     475000
# 635        0    Mar   2007        WD        Abnorml     200000
# 1009       0    Jun   2006        WD         Normal     102000
#
# [5 rows x 81 columns]

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(15, 6), ncols=2, sharey=False, sharex=False)


sns.residplot(x="LowQualFinSF", y='SalePrice', data=df, ax=ax1)
sns.residplot(x="LowQualFinSF", y='SalePrice', data=df, ax=ax2)

plt.show()

# %%
plt.scatter(x="SaleCondition", y="SalePrice", data=df )

# %%
df.query("GrLivArea>4400")
#523,1298
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 523          523       SC60       RL          130    40094   Pave   NaN
# 1182        1182       SC60       RL          160    15623   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 523       IR1         Bnk    AllPub  ...        0     No     No          No
# 1182      IR1         Lvl    AllPub  ...      555     Ex  MnPrv          No
# 1298      IR3         Bnk    AllPub  ...      480     Gd     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 523        0    Oct   2007       New        Partial     184750
# 1182       0    Jul   2007        WD        Abnorml     745000
# 1298       0    Jan   2008       New        Partial     160000
#
# [3 rows x 81 columns]

# %%
plt.scatter(x="BsmtFullBath", y="SalePrice", data=df )

# %%
df.query("BsmtFullBath ==3.0")
#738
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 738         738       SC90       RL           60    10800   Pave   NaN
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 738      Reg         Lvl    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 738       0    Mar   2009        WD         Alloca     179000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="BsmtHalfBath", y="SalePrice", data=df )

# %%
df.query("BsmtHalfBath ==2.0")
#597,954
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 597         597      SC120       RL           53     3922   Pave   NaN
# 954         954       SC90       RL           35     9400   Pave   NaN
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 597      Reg         Lvl    AllPub  ...        0     No    No          No
# 954      IR1         Lvl    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 597       0    Feb   2007       New        Partial     194201
# 954       0    Oct   2006        WD        AdjLand     127500
#
# [2 rows x 81 columns]

# %%
plt.scatter(x="FullBath", y="SalePrice", data=df )

# %%
plt.scatter(x="HalfBath", y="SalePrice", data=df )

# %%
plt.scatter(x="BedroomAbvGr", y="SalePrice", data=df )

# %%
df.query("BedroomAbvGr  ==8.0")
#635
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 635         635      SC190       RH           60    10896   Pave  Pave
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 635      Reg         Bnk    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635       0    Mar   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="KitchenAbvGr", y="SalePrice", data=df )

# %%
df.query("KitchenAbvGr   ==3.0")
#48,809
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 48           48      SC190       RM           33     4456   Pave   NaN
# 809         809       SC75       RM           90     8100   Pave   NaN
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 48       Reg         Lvl    AllPub  ...        0     No     No          No
# 809      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 48        0    Jun   2009       New        Partial     113000
# 809       0    Nov   2009        WD         Normal     106000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x="TotRmsAbvGrd", y="SalePrice", data=df )

# %%
df.query("TotRmsAbvGrd ==14.0")
#635
# Out:
#      Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 635         635      SC190       RH           60    10896   Pave  Pave
#
#     LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 635      Reg         Bnk    AllPub  ...        0     No    No          No
#
#     MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635       0    Mar   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="Fireplaces", y="SalePrice", data=df )

# %%
plt.scatter(x="GarageYrBlt", y="SalePrice", data=df)

# %%
plt.scatter(x="GarageCars", y="SalePrice", data=df)

# %%
plt.scatter(x="GarageArea", y="SalePrice", data=df)

# %%
df.query("GarageArea>1200")
#1061,1190
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 581          581       SC20       RL           98    12704   Pave   NaN
# 825          825       SC20       RL          114    14803   Pave   NaN
# 1061        1061       SC30  C (all)          120    18000   Grvl   NaN
# 1190        1190      SC190       RL            0    32463   Pave   NaN
# 1298        1298       SC60       RL          313    63887   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 581       Reg         Lvl    AllPub  ...        0     No    No          No
# 825       Reg         Lvl    AllPub  ...        0     No    No          No
# 1061      Reg         Low    AllPub  ...        0     No    No        Shed
# 1190      Reg         Low    AllPub  ...        0     No    No          No
# 1298      IR3         Bnk    AllPub  ...      480     Gd    No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 581        0    Aug   2009       New        Partial     253293
# 825        0    Jun   2008       New        Partial     385000
# 1061     560    Aug   2008     ConLD         Normal      81000
# 1190       0    Mar   2007        WD         Normal     168000
# 1298       0    Jan   2008       New        Partial     160000
#
# [5 rows x 81 columns]

# %%
df
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 2              2       SC60       RL           68    11250   Pave   NaN
# 3              3       SC70       RL           60     9550   Pave   NaN
# 4              4       SC60       RL           84    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave   NaN
# 1456        1456       SC20       RL           85    13175   Pave   NaN
# 1457        1457       SC70       RL           66     9042   Pave   NaN
# 1458        1458       SC20       RL           68     9717   Pave   NaN
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# 0         Reg         Lvl    AllPub  ...        0     No     No          No
# 1         Reg         Lvl    AllPub  ...        0     No     No          No
# 2         IR1         Lvl    AllPub  ...        0     No     No          No
# 3         IR1         Lvl    AllPub  ...        0     No     No          No
# 4         IR1         Lvl    AllPub  ...        0     No     No          No
# ...       ...         ...       ...  ...      ...    ...    ...         ...
# 1455      Reg         Lvl    AllPub  ...        0     No     No          No
# 1456      Reg         Lvl    AllPub  ...        0     No  MnPrv          No
# 1457      Reg         Lvl    AllPub  ...        0     No  GdPrv        Shed
# 1458      Reg         Lvl    AllPub  ...        0     No     No          No
# 1459      Reg         Lvl    AllPub  ...        0     No     No          No
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0    Feb   2008        WD         Normal     208500
# 1          0    May   2007        WD         Normal     181500
# 2          0    Sep   2008        WD         Normal     223500
# 3          0    Feb   2006        WD        Abnorml     140000
# 4          0    Dec   2008        WD         Normal     250000
# ...      ...    ...    ...       ...            ...        ...
# 1455       0    Aug   2007        WD         Normal     175000
# 1456       0    Feb   2010        WD         Normal     210000
# 1457    2500    May   2010        WD         Normal     266500
# 1458       0    Apr   2010        WD         Normal     142125
# 1459       0    Jun   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
plt.scatter(x="WoodDeckSF", y= "SalePrice", data=df)

# %%
df.query("WoodDeckSF>800")
#53 may be
# Out:
#     Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 53          53       SC20       RL           68    50271   Pave   NaN
#
#    LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 53      IR1         Low    AllPub  ...        0     No    No          No
#
#    MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 53       0    Nov   2006        WD         Normal     385000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x="OpenPorchSF", y="SalePrice", data=df)

# %%
df.query("OpenPorchSF>=500")
495
# Out:
# 495

# %%
plt.scatter(x="EnclosedPorch", y="SalePrice", data=df )

# %%
df.query("EnclosedPorch  >500")
197
# Out:
# 197

# %%
plt.scatter(x="3SsnPorch", y="SalePrice", data=df )

# %%
plt.scatter(x="ScreenPorch", y="SalePrice", data=df )

# %%
plt.scatter(x="PoolArea", y="SalePrice", data=df )

# %%
plt.scatter(x="MiscVal", y="SalePrice", data=df )

# %%
# Visualize the distribution of house prices
plt.figure(figsize=(10, 6))
sns.histplot(df['SalePrice'], kde=True)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
stats.zscore(df["MiscVal"]).sort_values()
# Out:
# 0       -0.087688
# 976     -0.087688
# 975     -0.087688
# 974     -0.087688
# 973     -0.087688
#           ...
# 890      3.944952
# 1457     4.953112
# 705      6.969431
# 1230    16.647766
# 346     31.165268
# Name: MiscVal, Length: 1460, dtype: float64

# %%
plt.scatter(x="YrSold", y="SalePrice", data=df )
#346

# %% [markdown]
# ## now, deleting all the outlier

# %% [markdown]
# ## Droping outliers from every column
# ### marked by  us using scatter plot

# %%
df.rename(columns={"Unnamed: 0":"HouseID"},inplace=True)
df
# Out:
#       HouseID MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
# ...       ...        ...      ...          ...      ...    ...   ...      ...
# 1455     1455       SC60       RL           62     7917   Pave   NaN      Reg
# 1456     1456       SC20       RL           85    13175   Pave   NaN      Reg
# 1457     1457       SC70       RL           66     9042   Pave   NaN      Reg
# 1458     1458       SC20       RL           68     9717   Pave   NaN      Reg
# 1459     1459       SC20       RL           75     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0     No     No          No       0
# 1            Lvl    AllPub  ...        0     No     No          No       0
# 2            Lvl    AllPub  ...        0     No     No          No       0
# 3            Lvl    AllPub  ...        0     No     No          No       0
# 4            Lvl    AllPub  ...        0     No     No          No       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0     No     No          No       0
# 1456         Lvl    AllPub  ...        0     No  MnPrv          No       0
# 1457         Lvl    AllPub  ...        0     No  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0     No     No          No       0
# 1459         Lvl    AllPub  ...        0     No     No          No       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       Feb   2008        WD         Normal     208500
# 1       May   2007        WD         Normal     181500
# 2       Sep   2008        WD         Normal     223500
# 3       Feb   2006        WD        Abnorml     140000
# 4       Dec   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455    Aug   2007        WD         Normal     175000
# 1456    Feb   2010        WD         Normal     210000
# 1457    May   2010        WD         Normal     266500
# 1458    Apr   2010        WD         Normal     142125
# 1459    Jun   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
values = [934,1298,294,313,335,451,706,249,523,378,1183,692,185,297,440,738,597,954,635,48,809,1061,1190,53,495,197,346]

# %%
df = df[~df.HouseID.isin(values)]
df = df[~df.HouseID.isin(values)]

# %%
df.rename(columns={"Unnamed: 0":"HouseID"},inplace=True)
df
# Out:
#       HouseID MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
# ...       ...        ...      ...          ...      ...    ...   ...      ...
# 1455     1455       SC60       RL           62     7917   Pave   NaN      Reg
# 1456     1456       SC20       RL           85    13175   Pave   NaN      Reg
# 1457     1457       SC70       RL           66     9042   Pave   NaN      Reg
# 1458     1458       SC20       RL           68     9717   Pave   NaN      Reg
# 1459     1459       SC20       RL           75     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0     No     No          No       0
# 1            Lvl    AllPub  ...        0     No     No          No       0
# 2            Lvl    AllPub  ...        0     No     No          No       0
# 3            Lvl    AllPub  ...        0     No     No          No       0
# 4            Lvl    AllPub  ...        0     No     No          No       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0     No     No          No       0
# 1456         Lvl    AllPub  ...        0     No  MnPrv          No       0
# 1457         Lvl    AllPub  ...        0     No  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0     No     No          No       0
# 1459         Lvl    AllPub  ...        0     No     No          No       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       Feb   2008        WD         Normal     208500
# 1       May   2007        WD         Normal     181500
# 2       Sep   2008        WD         Normal     223500
# 3       Feb   2006        WD        Abnorml     140000
# 4       Dec   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455    Aug   2007        WD         Normal     175000
# 1456    Feb   2010        WD         Normal     210000
# 1457    May   2010        WD         Normal     266500
# 1458    Apr   2010        WD         Normal     142125
# 1459    Jun   2008        WD         Normal     147500
#
# [1433 rows x 81 columns]

# %% [markdown]
# ## Imputation process started through
# ### mean and median for numeric data and mode for catagorical data
# ### as required

# %%
pd.DataFrame(df.isnull().sum().sort_values(ascending= False).head(40))
# Out:
#                   0
# Alley          1345
# MasVnrType      857
# GarageYrBlt      76
# Electrical        1
# KitchenAbvGr      0
# GarageType        0
# FireplaceQu       0
# Fireplaces        0
# Functional        0
# TotRmsAbvGrd      0
# KitchenQual       0
# HouseID           0
# GarageFinish      0
# HalfBath          0
# FullBath          0
# BsmtHalfBath      0
# BsmtFullBath      0
# GrLivArea         0
# LowQualFinSF      0
# 2ndFlrSF          0
# BedroomAbvGr      0
# GarageArea        0
# GarageCars        0
# PoolQC            0
# SaleCondition     0
# SaleType          0
# YrSold            0
# MoSold            0
# MiscVal           0
# MiscFeature       0
# Fence             0
# PoolArea          0
# GarageQual        0
# ScreenPorch       0
# 3SsnPorch         0
# EnclosedPorch     0
# OpenPorchSF       0
# WoodDeckSF        0
# PavedDrive        0
# GarageCond        0

# %%
sn.catplot(data=df, x="Alley", y= "SalePrice", kind="box")

# %%
df["MasVnrType"].unique()
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
df["MasVnrType"].fillna("no", inplace= True)

# %%
sn.catplot(data=df, x="MasVnrType", y= "SalePrice", kind="box")

# %%
df["Electrical"].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
import warnings
warnings.filterwarnings("ignore")
# lets see what is in the alley from unique funtion
df["Alley"].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df["Alley"].fillna("no", inplace =True)

# %%
# now we can see there is no null value after imputation
df["Alley"].isnull().sum()
# Out:
# 0

# %%
# 'df' is your DataFrame that contains the data
# Create a boxplot with SalePrice on the y-axis and Alley on the x-axis
sn.catplot(data=df,x="Alley",y="SalePrice", kind="box" )

# %%
df["MasVnrType"].unique()
# Out:
# array(['BrkFace', 'no', 'Stone', 'BrkCmn'], dtype=object)

# %%
df["MasVnrType"].fillna("no", inplace =True)

# %%
sn.catplot(data=df,x="MasVnrType",y="SalePrice", kind="box" )

# %%
#his code will give you the correlation coefficient between the GarageYrBlt and YearBuilt columns.
# A coefficient close to 1 or -1 indicates a strong relationship, while a coefficient close to 0 indicates a weak relationship.
# and we have found between 1 and -1
df["GarageYrBlt"]. corr(df["YearBuilt"])
# Out:
# 0.8286542611347045

# %%
df["Electrical"].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
#  I am usig term (circuit breaker) for null or nan in the electric colmn

df["Electrical"].fillna("SBrkr", inplace= True)

# %%
sn.catplot(data=df, x="Electrical", y= "SalePrice", kind="box")

# %% [markdown]
# ## Remove unnecessory cloumm
# ### which is more than 70% null value or almost identical column

# %%
df.columns
# Out:
# Index(['HouseID', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
models = ['Linear Regression', 'Decision Tree', 'Random Forest']
mae_values = [21549.389438772603, 26522.95205479452, 17687.66955479452]
rmse_values = [34369.464158808434, 39317.56299278709, 28534.840264550443]
model_comparison = pd.DataFrame({'Model': models,'MAE': mae_values,'RMSE': rmse_values})
print(model_comparison)
best_model = model_comparison.loc[model_comparison['MAE'].idxmin()] #idxmin() finds the index of the minimum MAE value.
print("nBest Model based on MAE and RMSE:")
print(best_model)
# Out:
#                Model           MAE          RMSE
# 0  Linear Regression  21549.389439  34369.464159
# 1      Decision Tree  26522.952055  39317.562993
# 2      Random Forest  17687.669555  28534.840265
# nBest Model based on MAE and RMSE:
# Model    Random Forest
# MAE       17687.669555
# RMSE      28534.840265
# Name: 2, dtype: object

# %% [markdown]
# # feature engineering

# %%
df["Houseage"]=df['YrSold'] - df['YearBuilt']

# %%
df["HouseRemodleAge"]=df['YrSold']- df['YearRemodAdd']

# %%
df["TotalSf"]=df[ '1stFlrSF']+ df['2ndFlrSF'] +df['BsmtFinSF1']+df['BsmtFinSF2']

# %%
df['TotalArea']=df[ 'GrLivArea']+df['TotalBsmtSF']

# %%
# Total number of bathrooms = number of full bathrooms + 0.5 * number of half bathrooms
    # + number of bathrooms in basement + 0.5 * number of half bathrooms in the basement.
df["TotalBaths"]=df['BsmtFullBath']+df['FullBath']+ 0.5*(df['BsmtHalfBath']+df['HalfBath'])

# %%
df["TotalPorchSF"]=df['OpenPorchSF']+df['EnclosedPorch']+df['3SsnPorch']+df['ScreenPorch']+df['WoodDeckSF']

# %%
df= df.drop(columns=['YrSold','YearBuilt','YearRemodAdd','1stFlrSF','2ndFlrSF','BsmtFinSF1','BsmtFinSF2',
                   'GrLivArea','TotalBsmtSF','BsmtFullBath','FullBath','BsmtHalfBath','HalfBath',
                    'OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','WoodDeckSF'])

# %%
## We have added certain features which are quite intuitive and are taken 
#into consideration in real life too while buying the house. Like what's the total area in square feet of the house 
#or how many bathrooms are there in the house. We could also look for the availability of swimming pool, garage
#fireplace and basement in the house. That's why I have added such features in the dataset

# %% [markdown]
# # correlation in numeric data through heat map

# %%
correlation_matrix=df.corr(numeric_only=True)
plt.figure(figsize=(20,12))
sn.heatmap(correlation_matrix,annot=True,cmap="coolwarm",fmt=(".2f"))
# Out:
# <Axes: >

# %%
# as we can see garageArea and garageCar are highely correlated so 
# we may drop one of them.

# %%
df= df.drop(columns=['GarageArea'])

# %% [markdown]
# # Visualisation from Histogram

# %%
sn.histplot(df,
 x=df["SalePrice"])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ## The np.log1p function comes from the NumPy library and computes the natural logarithm
# ### This transformation is often used in data preprocessing to reduce the skewness of the distribution of the data.
# ### In other words, if the "SalePrice" data is heavily skewed (i.e., not normally distributed), applying the natural logarithm can make it more
# ### normally distributed, which is often beneficial for various statistical models

# %%
df["SalePrice"]=np.log1p(df["SalePrice"])

# %%
sn.histplot(df,x=df["SalePrice"])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
df.dtypes[df.dtypes=='object']
# Out:
# MSSubClass       object
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# PoolQC           object
# Fence            object
# MiscFeature      object
# MoSold           object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
df.dtypes[df.dtypes !='object']
# Out:
# HouseID              int64
# LotFrontage          int64
# LotArea              int64
# OverallQual          int64
# OverallCond          int64
# MasVnrArea           int64
# BsmtUnfSF            int64
# LowQualFinSF         int64
# BedroomAbvGr         int64
# KitchenAbvGr         int64
# TotRmsAbvGrd         int64
# Fireplaces           int64
# GarageYrBlt        float64
# GarageCars           int64
# PoolArea             int64
# MiscVal              int64
# SalePrice          float64
# Houseage             int64
# HouseRemodleAge      int64
# TotalSf              int64
# TotalArea            int64
# TotalBaths         float64
# TotalPorchSF         int64
# dtype: object

# %% [markdown]
# ### Making pipeline throgh ordinalEncoder and oneHotencoder

# %%
ode_cols=['LotShape','LandContour','Utilities','LandSlope','BsmtQual','BsmtFinType1','CentralAir','Functional','FireplaceQu',
'GarageQual','GarageFinish','PavedDrive','ExterCond','KitchenQual','BsmtExposure','HeatingQC','BsmtExposure','ExterQual',
'BsmtCond']

# %%
ohe_cols=["Street",'LotConfig','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','Exterior1st','Exterior2nd',
'MasVnrType','Foundation','Electrical','SaleType'
'MSZoning','SaleCondition','Heating','GarageType','RoofMatl']

# %%
num_cols = df.select_dtypes(include=["int64", "float64"]).columns
num_cols = num_cols.drop('SalePrice')

# %%
num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
ode_pipeline=Pipeline(steps=[('impute',SimpleImputer(strategy='Most_frequent')),
    ('ode', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1
    ))])

# %%
ohe_pipeline=Pipeline(steps=[
    ('impute', SimpleImputer(strategy='Most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore',sparse_output=False))
])

# %%
col_trans = ColumnTransformer(transformers=[
    ("num_p", num_pipeline, num_cols),
    ("ode_p", ode_pipeline, ode_cols),
    ("ohe_p", ohe_pipeline, ohe_cols),
    ],
    remainder="passthrough",
    n_jobs=-1)

# %%
pipeline=Pipeline(steps=[
    ('preprocessing',col_trans )
])

# %% [markdown]
# ## SalePrice Feature Analysis

# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec

def three_chart_plot(df, feature):
    fig = plt.figure(constrained_layout=True, figsize=(12, 8))
    grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)
    
    ax1 = fig.add_subplot(grid[0, :2])
    ax1.set_title('Histogram')
    
    sn.distplot(df.loc[:, feature], norm_hist=True, ax=ax1)
    ax1.axvline(x=df[feature].mean(), c='red')
    ax1.axvline(x=df[feature].median(), c='green')
    
    ax2 = fig.add_subplot(grid[1, :2])
    ax2.set_title('QQ_plot')
    stats.probplot(df.loc[:, feature], plot=ax2)

    ax3 = fig.add_subplot(grid[:, 2])
    ax3.set_title('Box Plot')
    sn.boxplot(y=df.loc[:, feature], ax=ax3)
    
    plt.show()

# Example usage
three_chart_plot(df, 'SalePrice')

# %%
from scipy.stats import skew
print("Skewness of the SalesPrice is", df['SalePrice'].skew())
# Out:
# Skewness of the SalesPrice is 0.14161970565552856

# %%
num = df.select_dtypes(exclude = 'object')
corr_num = num.corr()

f, ax = plt.subplots(figsize = (17, 1))

sn.heatmap(corr_num.sort_values(by = ['SalePrice'], ascending = False).head(1), cmap='PuRd_r')

plt.title('Correlation of Numerical Features with the Target', weight = 'bold', fontsize = 18)
plt.xticks(weight='bold')
plt.yticks(weight='bold', color='dodgerblue', rotation=0)

plt.show()

# %%
# Visualize the relationship between Total Area and Sale Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['TotalArea'], y=df['SalePrice'])
plt.title('Total Area vs Sale Price')
plt.xlabel('Total Area')
plt.ylabel('Sale Price')
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# Calculate correlation matrix for numeric columns
correlation = numeric_df.corr()['SalePrice'].sort_values(ascending=False).to_frame().head(10)

# Apply the color map
cmap = sns.light_palette("cyan", as_cmap=True)
sn = correlation.style.background_gradient(cmap=cmap)

# Display the styled DataFrame
sn
# Out:
# <style type="text/css">
# #T_acae6_row0_col0 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_acae6_row1_col0 {
#   background-color: #4afbfb;
#   color: #000000;
# }
# #T_acae6_row2_col0 {
#   background-color: #4bfbfb;
#   color: #000000;
# }
# #T_acae6_row3_col0 {
#   background-color: #6bf9f9;
#   color: #000000;
# }
# #T_acae6_row4_col0 {
#   background-color: #81f8f8;
#   color: #000000;
# }
# #T_acae6_row5_col0 {
#   background-color: #84f8f8;
#   color: #000000;
# }
# #T_acae6_row6_col0 {
#   background-color: #bbf5f5;
#   color: #000000;
# }
# #T_acae6_row7_col0 {
#   background-color: #bef5f5;
#   color: #000000;
# }
# #T_acae6_row8_col0 {
#   background-color: #d8f4f4;
#   color: #000000;
# }
# #T_acae6_row9_col0 {
#   background-color: #e8f3f3;
#   color: #000000;
# }
# </style>
# <table id="T_acae6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acae6_level0_col0" class="col_heading level0 col0" >SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acae6_level0_row0" class="row_heading level0 row0" >SalePrice</th>
#       <td id="T_acae6_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row1" class="row_heading level0 row1" >OverallQual</th>
#       <td id="T_acae6_row1_col0" class="data row1 col0" >0.821479</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row2" class="row_heading level0 row2" >TotalArea</th>
#       <td id="T_acae6_row2_col0" class="data row2 col0" >0.821110</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row3" class="row_heading level0 row3" >TotalSf</th>
#       <td id="T_acae6_row3_col0" class="data row3 col0" >0.744684</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row4" class="row_heading level0 row4" >GarageCars</th>
#       <td id="T_acae6_row4_col0" class="data row4 col0" >0.689283</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row5" class="row_heading level0 row5" >TotalBaths</th>
#       <td id="T_acae6_row5_col0" class="data row5 col0" >0.682624</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row6" class="row_heading level0 row6" >GarageYrBlt</th>
#       <td id="T_acae6_row6_col0" class="data row6 col0" >0.550844</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row7" class="row_heading level0 row7" >TotRmsAbvGrd</th>
#       <td id="T_acae6_row7_col0" class="data row7 col0" >0.542696</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row8" class="row_heading level0 row8" >Fireplaces</th>
#       <td id="T_acae6_row8_col0" class="data row8 col0" >0.481853</td>
#     </tr>
#     <tr>
#       <th id="T_acae6_level0_row9" class="row_heading level0 row9" >MasVnrArea</th>
#       <td id="T_acae6_row9_col0" class="data row9 col0" >0.441606</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Drop rows with missing values in 'Houseage' or 'SalePrice'
df_filtered = df.dropna(subset=['Houseage', 'SalePrice'])

# Create the scatter plot
plt.figure(figsize=(15, 6))
plt.scatter(x='Houseage', y='SalePrice', data=df_filtered, color='crimson', alpha=0.4)
plt.title('Relationship between Houseage and Sale Price', weight='bold', fontsize=10)
plt.xlabel('Area of the house', weight='bold')
plt.ylabel('Sale Price', weight='bold')
plt.show()

# %%
# Drop rows with missing values in 'Houseage' or 'SalePrice'
df_filtered = df.dropna(subset=['TotalArea', 'SalePrice'])

# Create the scatter plot
plt.figure(figsize=(15, 6))
plt.scatter(x='TotalArea', y='SalePrice', data=df_filtered, color='crimson', alpha=0.4)
plt.title('Relationship between TotalArea and Sale Price', weight='bold', fontsize=10)
plt.xlabel('Area of the house', weight='bold')
plt.ylabel('Sale Price', weight='bold')
plt.show()

# %% [markdown]
# ### Now let's make sure that the target variable follows a normal distribution. In order to make a feature follow normal distribution, we will perform log transformation.

# %%
plt.figure(figsize = ((15, 10)))
df.boxplot(by = 'OverallQual', column = 'SalePrice')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def horizontal_plot(df, column, palette, title):
    plt.figure(figsize=(10, 6))
    sns.countplot(y=df[column], palette=palette, order=df[column].value_counts().index)
    plt.title(title, weight='bold')
    plt.xlabel('Count', weight='bold')
    plt.ylabel(column, weight='bold')
    plt.show()

# Example usage
horizontal_plot(df, 'GarageType', 'terrain', 'Garage Type')

# %%
def evaluation(model, x_train_std, y_train, x_test, y_test, train = True):
    if train == True:
        pred = model.predict(x_train_std)
        
        print("Train Result:\n=======")
        print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_train, pred))}")
        print("_______________________________________________")
        print(f"Mean Squared Error: {mean_squared_error(y_train, pred)}")
        print("_______________________________________________")
        print(f"Mean Absolute Error: \n{mean_absolute_error(y_train, pred)}")
        print("_______________________________________________")
        
    print()
    
    if train == False:
        pred = model.predict(x_test)
        
        print("Test Result:\n================================================")
        print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, pred))}")
        print("_______________________________________________")
        print(f"Mean Squared Error: {mean_squared_error(y_test, pred)}")
        print("_______________________________________________")
        print(f"Mean Absolute Error: \n{mean_absolute_error(y_test, pred)}")
        print("_______________________________________________")

# %%
models = ['Linear Regression', 'Decision Tree', 'Random Forest']
mae_values = [21549.389438772603, 26522.95205479452, 17687.66955479452]
rmse_values = [34369.464158808434, 39317.56299278709, 28534.840264550443]
model_comparison = pd.DataFrame({'Model': models,'MAE': mae_values,'RMSE': rmse_values})
print(model_comparison)
best_model = model_comparison.loc[model_comparison['MAE'].idxmin()] #idxmin() finds the index of the minimum MAE value.
print("nBest Model based on MAE and RMSE:")
print(best_model)
# Out:
#                Model           MAE          RMSE
# 0  Linear Regression  21549.389439  34369.464159
# 1      Decision Tree  26522.952055  39317.562993
# 2      Random Forest  17687.669555  28534.840265
# nBest Model based on MAE and RMSE:
# Model    Random Forest
# MAE       17687.669555
# RMSE      28534.840265
# Name: 2, dtype: object
